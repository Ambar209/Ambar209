# %% [markdown]
# <a href="https://colab.research.google.com/github/Ambar209/Ambar209/blob/main/Assignment_Data_Structure_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1 write a code to reverse a string
a="pwskills"
a[::-1]
#Q2 Write a code to count the vowels in a string
string="pwskills"
vowels="aeiouAEIOU"
count=sum(string.count(vowel) for vowel in vowels)
print(count)
#Q3 write a code to check if a given string is a palindrome or not
input_string="madam"
if input_string==input_string[::-1]:
    print("it is a palindrome")
else:
    print("it is not a palindrome")
#Q4 write a code to check if two given anagrams oeachother
def are_anagrams(str1, str2):
    return sorted(str1) == sorted(str2)

string1 = "listen"
string2 = "silent"
if are_anagrams(string1, string2):
    print("The strings are anagrams.")
else:
    print("The strings are not anagrams.")
#Q5 write a code to find all occurance of a given substring wthin
#   another string
def count_occurrences(string, substring):
    count = 0
    start = 0
    while True:
        start = string.find(substring, start)
        if start == -1:
            break
        count += 1
        start += len(substring)

    return count
#Q6 Wrie a coe to prform basic string compression using the counts of repeated
#   characters
def compress_string(input_string):
    compressed_string = ""
    count = 1
    for i in range(1, len(input_string)):
        if input_string[i] == input_string[i - 1]:
            count += 1
        else:
            compressed_string += input_string[i - 1]
#Q7 write a code to determine if a string has all unique characters
def has_unique_characters(input_string):
    char_set = set()
    for char in input_string:
        if char in char_set:
            return False
        char_set.add(char)
    return True
#Q8 write a code to convert a given string to uppercase or lowercase
def convert_case(input_string, to_uppercase=True):
    if to_uppercase:
        return input_string.upper()
    else:
        return input_string.lower()
#Q9 write a code to count a number of words in a string
def count_words(input_string):
    words = input_string.split()
    return len(words)
#Q10 write a code to concatenate two string without using + operator
def concatenate_strings(str1, str2):
    return str1 + str2
#Q11 Write a code to remove all occurrences of a specific element from a list
def remove_element(input_list, element_to_remove):
    return [x for x in input_list if x != element_to_remove]
#Q12 Implement a code to find the second largest number in a given
#    list of integer
def find_second_largest(numbers):
    if len(numbers) < 2:
        return None
#Q13 create a code to count the occurrences of each element in alist and
#    return a dictionary with elements as keys and their counts as values
def count_occurrences(input_list):
    occurrence_count = {}
    for element in input_list:
        if element in occurrence_count:
            occurrence_count[element] += 1
        else:
            occurrence_count[element] = 1
#Q14 write a code to reverse a list in-place without using any built-in
#    reverse function
def reverse_list(input_list):
    start = 0
    end = len(input_list) - 1
    while start < end:
        input_list[start], input_list[end] = input_list[end], input_list[start]
#Q15 Implement a code to find and remove duplicates from a list while
#    preserving the original order of elements
def remove_duplicates(input_list):
    unique_list = []
    for element in input_list:
        if element not in unique_list:
            unique_list.append(element)
    return unique_list
#Q16 create a code to check if a given list is sorted or not
def is_sorted(input_list):
    for i in range(len(input_list) - 1):
        if input_list[i] > input_list[i + 1]:
            return False
    return True
#Q17 write a code to merge two sorted lists into a single sorted list
def merge_sorted_lists(list1, list2):
    merged_list = []
    i = j = 0
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merged_list.append(list1[i])
            i += 1
        else:
            merged_list.append(list2[j])
            j += 1
            merged_list.extend(list1[i:])
    merged_list.extend(list2[j:])
    return merged_list
#Q18 implement a code to find the intersection of two given list
def find_intersection(list1, list2):
    intersection = []
    for element in list1:
        if element in list2 and element not in intersection:
            intersection.append(element)
    return intersection
#Q19 create a code to find the union of two lists without duplicates
def find_union(list1, list2):
    union = []
    for element in list1:
        if element not in union:
            union.append(element)
            for element in list2:
        if element not in union:
            union.append(element)
    return union
#Q20 write a code to shuffle a given list randomly without using any
#    built in shuffle funtion
import random
def shuffle_list(input_list):
    shuffled_list = input_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list
#Q21 write a code that takes two tuple as input and return a new tuple
#    containig elements that are common to both input tuples
def find_common_elements(tuple1, tuple2):
    common_elements = []
    for element in tuple1:
        if element in tuple2 and element not in common_elements:
            common_elements.append(element)
    return tuple(common_elements)
#Q22 create a code that prompts the user to enter two sets of integers
#    seperated by commas then print the intersection of these two sets
set1_input = input("Enter the first set of integers separated by commas: ")
set2_input = input("Enter the second set of integers separated by commas: ")
set1 = set(map(int, set1_input.split(',')))
set2 = set(map(int, set2_input.split(',')))
intersection = set1.intersection(set2)
print("Intersection of the two sets:", intersection)

#Q23 write a code to cocatenate two tuples the function should take two
#    tuples as input and return a new tuple containing elements from
#    both input tuples
def concatenate_tuples(tuple1, tuple2):
    concatenated_tuple = tuple1 + tuple2
    return concatenated_tuple
#Q24 develop a code that prompts the user to input two  sets of string then
#    print the elements that are present in the first set but not in
#    the second set
set1_input = input("Enter the first set of strings separated by commas: ")
set2_input = input("Enter the second sets of string separated by commas:")
set1 = get_set1_from_input(set1_input)

#Q25 create a code that takes a tuple and two integers as input the function
#    should return a new tuple containing elements from the original tuple
#    within the specified range of indices
def extract_elements_within_range(input_tuple, start_index, end_index):
    return input_tuple[start_index:end_index + 1]
    return new_tuple

#Q26 write a code that prompts the user to input two sets of character then
#    print the union of these two sets
# Out:
#   File "<ipython-input-1-70ff171095ff>", line 135
#     if element not in union:
#     ^
# IndentationError: expected an indented block after 'for' statement on line 134
