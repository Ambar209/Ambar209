# %% [markdown]
# <a href="https://colab.research.google.com/github/Ambar209/Ambar209/blob/main/Assignment_data_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ambr Raza
#Github Account Ambar209
#Q1: Discuss String slicing and provide examples
#Answer: String slicing is a powerful feature in pythonthat allow you to
#        extract specific parts of astring. it works by specifing a
#      range of indices andextracting the charactersthat fall within the range

text = "Hello, world!"
slice = text[0:5]
print(slice)
#o/p: Hello

text = "Hello, world!"
slice = text[7:]
print(slice)
#o/p: world!

text = "Hello, world!"
slice = text[:5]
print(slice)
#o/p: Hello

text = "Hello, world!"
slice = text[::2]
print(slice)
#o/p: Hlo ol!

text = "Hello, world!"
slice = text[::-1]
print(slice)

#Q2: Explain the ket features of list in python
#Answer:  List in python are flexible powerful, and easy to use their ability to
#         store hetrogeneous data ,grow dynamically ,and support various oprations
#         makes them a fundamental data structure in python
#      EX:1
# ordered
my_list = [1, 2, 3, 4, 5]
print(my_list[1])
#o/p 2

# mutable
my_list = [1, 2, 3, 4, 5]
my_list[0] = 10
print(my_list)
#o/p: [10, 2, 3, 4, 5]

#Dynamic Size
my_list = [1, 2, 3, 4, 5]
my_list.append(6)
print(my_list)
#o/p: [1, 2, 3, 4, 5, 6]

#Heterogeneous Data
my_list = [1, "hello", 3.14, True]
print(my_list)
#o/p: [1, 'hello', 3.14, True]

#Nested Lists
my_list = [1, [2, 3], 4, 5]
print(my_list[1][0])
#o/p 2,3,1

#List Comprehension
my_list = [x for x in range(10) if x % 2 == 0]
print(my_list)
#o/p: [0, 2, 4, 6, 8]

#Q3:Describe how to access,modify, and delete elements in alist with example
#Answer:  1   Accessing Element in list
my_list = [1, 2, 3, 4, 5]
print(my_list[0])
o/p: 1

#modifing element in list
my_list = [1, 2, 3, 4, 5]
my_list[0] = 10
print(my_list)
#o/p: [10, 2, 3, 4, 5]

#Deleting element in list
my_list = [1, 2, 3, 4, 5]
del my_list[0]
print(my_list)
#o/p: [2, 3, 4, 5]

#Q4: COmpare and contrast tuples and lists with examples
#answer: Feature                      List                   Tuple
 #       Mutability                   mutable               Immutable
 #       syntax square               barackets[]          parentheses()
#        performance                 slightly slower         faster
 #       Method              Many modification method      limited method
 #       memory usage            more memory                 less memory
#Ex: Mutability
my_list = [1, 2, 3, 4, 5]
my_list[0] = 10
print(my_list)
#o/p: [10, 2, 3, 4, 5]

#syntax
my_tuple = (1, 2, 3, 4, 5)
print(my_tuple[0])
o/p: 1
my_list = [1, 2, 3, 4, 5]
my_list[0] = 10
print(my_list)
#o/p: [10, 2, 3, 4, 5]

#Immutable
my_tuple = (1, 2, 3, 4, 5)
my_tuple[0] = 10
print(my_tuple)
o/p: TypeError: 'tuple' object does not support item assignment

#Method
my_list = [1, 2, 3, 4, 5]
my_list[0] = 10
print(my_list)
#o/p: [10, 2, 3, 4, 5]


#Q5: Describe the key features of sets nd provide examples of their use

#Answer sets in python are versetile and efficient way to store unique elements
# and  perform sets operation they are particularly useful when dealing with
#large data set ,performing membership tests and working
#with collections of unique items
Ex:1 Unorderd
my_set = {1, 2, 3, 4, 5}
print(my_set)
#o/p: {1, 2, 3, 4, 5}
#(order may vary)

#2 Mutable
my_set = {1, 2, 3, 4, 5}
my_set.add(6)
print(my_set)
#o/p: {1, 2, 3, 4, 5, 6}

#3 Immutable
my_set = {1, 2, 3, 4, 5}
my_set[0] = 10
print(my_set)
#o/p: TypeError: 'set' object does not support item assignment

#4 Efficient Membership Testing
my_set = {1, 2, 3, 4, 5}
print(1 in my_set)
o/p: True

#5 Unique Elements
my_set = {1, 2, 3, 4, 5, 1, 2, 3}
print(my_set)
#o/p: {1, 2, 3, 4, 5}

#Q6: Discuss the use cases of tuple and sets in python programming
#Answer   Use cases of tuple in python
#         tuples are ++immutable and ordered collections making them suitable
#         for specific scenios where immutability performance and fixed
#         structure are important
#1 fixed Dat structur
coordinate = (10.0, 20.0)
color = (255, 0, 0)
print(coordinate)
print(color)
#o/p: (255, 0, 0)

#2 Returning Function Values from Function
def divide(a, b):
    return a / b

result = divide(10, 2)
print(result)
#3 Using tuple as keys  in dictionaries
my_dict = {(1, 2): "value1", (3, 4): "value2"}
print(my_dict[(1, 2)])
#o/p: value1

#4Ensuring Data integrity
def process_data(data):
    processed_data = tuple(data)
    return processed_data

original_data = [1, 2, 3, 4, 5]
processed_data = process_data(original_data)
print(processed_data)

#   Use cases of sets in python
#1 removing Duplicates from collection
my_list = [1, 2, 3, 4, 5, 1, 2, 3]
unique_set = set(my_list)
print(unique_set)
#o/p: {1, 2, 3, 4, 5}

#2 Efficient Membership Testing
my_set = {1, 2, 3, 4, 5}
print(1 in my_set)
o/p: True

#3 mathematical set operation
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}
union_set = set1.union(set2)
print(union_set)
#o/p: {1, 2, 3, 4, 5, 6, 7, 8}

#4 finding common elements
list1=[1,2,3,4,5]
list2=[4,5,6,7,8]
set1=set(list1)
set2=set(list2)
common_elements=set1.intersection(set2)
print(common_elements)
#o/p: {4, 5}

#Q7  describe how to add delete items in a dictionary with examples
 #1 Adding items to a dictionary
    my_dict = {"name": "John", "age": 30}
my_dict["city"] = "New York"
print(my_dict)
#o/p: {'name': 'John', 'age': 30, 'city': 'New York'}

#2 Modifying items in a dictionary
my_dict = {"name": "John", "age": 30}
my_dict["age"] = 31
print(my_dict)
#o/p: {'name': 'John', 'age': 31}

#3 Deleting items from a dictionary
my_dict = {"name": "John", "age": 30}
del my_dict["age"]
print(my_dict)
#o/p: {'name': 'John'}

#Q8  Discuss the importancxe of dictionary keys being immutable
#   and provcidse examples
#Answer  in python dictionary keys must be immutable because they are use
#     to create a hash value that allow for quick access to value if a key were
#      mutable its hash value can change over time leading to inconsistence and
#       making it impossible to reliably retrive the associate values
#1 hashing requirement
my_dict = {[1, 2, 3]: "value1"}
print(my_dict)
#o/p: TypeError: unhashable type: 'list'

#2 immutable keys
my_dict = {(1, 2, 3): "value1"}
print(my_dict)
#o/p: {(1, 2, 3): 'value1'}

#3 consistency in access
my_dict = {(1, 2, 3): "value1"}
print(my_dict[(1, 2, 3)])
#o/p: value1

#4 Avoiding returning Errors
my_dict = {"name": "John", "age": 30}
print(my_dict["city"])
#o/p: KeyError: 'city'

#5 mutable keys
my_dict = {["name"]: "John", "age": 30}
print(my_dict)
#o/p: TypeError: unhashable type: 'list'
