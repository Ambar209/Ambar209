# %% [markdown]
# <a href="https://colab.research.google.com/github/Ambar209/Ambar209/blob/main/Feature_Engineering_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1: What is a parameter
#
# Answer: A parameter is a variable that defines a model or system's behavior. In the context of machine learning, a parameter refers to the internal configuration or coefficients that are learned during training
#
# Q2: What is correlation
#     What does negative correlation mean
# Answer: Correlation is a statistical measure that describes the relationship between two variables. It shows how one variable changes in relation to another
#
# Negative correlation means that as one variable increases, the other decreases.
#
# Q3:Define Machine Learning. What are the main components in Machine Learning?
#
# Answer:
# Machine Learning (ML) is a field of artificial intelligence (AI) where computers learn from data to make predictions or decisions without being explicitly programmed for every task.
#
# Main Components of Machine Learning
# Data
# Model
# Training
# Features
#
# Q4: How does loss value help in determining whether the model is good or not?
#
# Answer:
# If the loss is high, it means the model is performing poorly.
# If the loss is low, it means the model is performing well.
#
# Q5: What are continuous and categorical variables?
#
# Answer:
# Continuous variables are numerical variables that can take any value within a range. They can have infinite possibilities, like height, weight, or temperature.
#
# Categorical variables are variables that represent categories or groups. They have a limited, fixed number of values, like colors (red, blue, green)
#
# Q6: How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# Answer:
# To handle categorical variables in Machine Learning, we need to convert them into a format that algorithms can understand
#
# One-Hot Encoding
# Label Encoding
# Target Encoding
#
# Q7: What do you mean by training and testing a dataset?
#
# Answer:
# Training a dataset means using a portion of the data to teach the model how to make predictions
#
# Testing is for checking performance.
#
# Q8: What is sklearn.preprocessing?
#
# Answer:
# sklearn.preprocessing is a module in the scikit-learn library that provides tools for preparing data before feeding it into a machine learning model
#
# Q9: What is a Test set
#
# Answer:
# A test set is a portion of the dataset that is used to evaluate the performance of a machine learning model after it has been trained
#
# Q10:How do we split data for model fitting (training and testing) in Python
#
# Answer:
#
#  we can split data for model fitting (training and testing) using the train_test_split function from scikit-learn.
#
# Q11: Why do we have to perform EDA before fitting a model to the data
#
# Answer:
# Exploratory Data Analysis (EDA) is important before fitting a model because it helps you
# Understand the data
# Choose the right model
# Feature selection
# Data transformation
#
# Q12: What is correlation
#
# Answer:
# Correlation is a statistical measure that describes the relationship between two variables. It shows how one variable changes in relation to another
#
# Q13: What does negative correlation mean
#
# Answer:
# Negative correlation means that as one variable increases, the other decreases
#
# Q14: How can you find correlation between variables in Python
#
# Answer:
# In Python, you can find the correlation between variables using Pandas' .corr() method
#
# Q15: What is causation? Explain difference between correlation and causation with an example
#
# Answer:
# Causation refers to a cause-and-effect relationship, where one event or variable directly causes another to happen
#
# Difference between Correlation and Causation
#
# Correlation means two variables are related in some way (they change together), but one does not necessarily cause the other
#
# Causation means one variable directly causes the change in another variable
# Example
# Correlation: There might be a correlation between ice cream sales and the number of people swimming. Both increase during summer, but eating ice cream doesnt cause people to swim.
# Causation: If you increase the temperature, more people may decide to swim. In this case, the temperature is the cause of swimming
#
# Q16: What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
# Answer:
# optimizers adjust the models weights during training to minimize the error, and different optimizers do this in different ways to improve training speed and accuracy
# Different Types of Optimizers
#
# Gradient Descent (GD)
#
# How it works: Updates model parameters by taking steps in the opposite direction of the gradient of the loss function
# Example: If the model makes an error, gradient descent moves the weights in the direction that reduces the error
#
# Stochastic Gradient Descent
# How it works: Updates parameters after each data point (instead of the full dataset like in GD).
#
# Example: Instead of computing gradients over the entire training set, it updates weights for each data point, speeding up training.
#
# Q17:What is sklearn.linear_model
#
# Answer:
# sklearn.linear_model provides tools for applying linear models to both regression
#
# Q18: What does model.fit() do? What arguments must be given
#
# Answer:
# model.fit() teaches the model to map the input data X to the target y during the training phase.
#
# X_train: The training data (features).
# y_train: The true labels (target values) for the training data.
#
# Q19: What does model.predict() do? What arguments must be given
#
# Answer:
# model.predict() gives the predicted values (outputs) based on the input data X.
#
# X_test: The features of the test data, which the model uses to predict outcome
#
# Q20: What are continuous and categorical variables
#
# Answer:
# Continuous variables are numerical variables that can take any value within a range. They can have infinite possibilities, like height, weight, or temperature.
#
# Categorical variables are variables that represent categories or groups. They have a limited, fixed number of values, like colors (red, blue, green)
#
# Q21: What is feature scaling? How does it help in Machine Learning
#
# Answer:
# feature scaling ensures all features contribute equally to the model, leading to better performance and faster training
#
# How it helps
#
# Improves model performance
# Speeds up convergence
# Prevents dominance of features
#
# Q22: How do we perform scaling in Python
#
# Answer:
# In Python, you can perform feature scaling using scikit-learn's StandardScaler (for standardization) or MinMaxScaler (for normalization)
#
# Q23: What is sklearn.preprocessing
#
# Answer:
# sklearn.preprocessing is a module in scikit-learn that provides tools for transforming and preparing data before feeding it into a machine learning model
#
# Q24: How do we split data for model fitting (training and testing) in Python
#
# Answer:
# we can split data for model fitting (training and testing) using the train_test_split function from scikit-learn.
#
# Q25: Explain data encoding
#
# Answer:
# encoding helps transform categorical data into a format that can be used by machine learning models.
#
#
# *   List item
# *   List item
